# %%
from matplotlib import pyplot as plt
from math import *

x = [x for x in range(-150, 150)]
def f(x):
    return -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
y = [f(i) for i in x]
plt.plot(y)
